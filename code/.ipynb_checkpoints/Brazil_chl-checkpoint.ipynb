# %%
#import packages

# !pip install netcdf4
import xarray as xr
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy import interpolate

# %%
brazil = pd.read_csv('Field_measurements_Lago_Curuai.csv', delimiter = ',', header = 29)
display(brazil)

#index data
lon = brazil['Longitude']
lat = brazil['Latitude']
temp = brazil['Temperature']
#chl = brazil['Chlorophyll_a']

chl = brazil.loc[brazil['Chlorophyll_a']<1500.0]
# Out:
#          Date   Time  Longitude  Latitude      TSS       ISS       OSS
# 0    20030925  10:25 -55.789501  -2.20678  35.3430  28.25000   7.09300  \
# 1    20030925  12:07 -55.852402  -2.19675  94.6200  59.34700  35.27300
# 2    20030925  12:30 -55.823399  -2.17569  49.8880  40.14000   9.74800
# 3    20030925  12:50 -55.836800  -2.16275  55.7920  41.19600  14.59600
# 4    20030925  13:40 -55.780701  -2.14625  48.0100  32.81800  15.19200
# ..        ...    ...        ...       ...      ...       ...       ...
# 290  20040619  13:25 -55.220901  -2.17781  12.4263   6.95750   5.46875
# 291  20040619  13:55 -55.155899  -2.19958  12.9225   8.09625   4.82625
# 292  20040619  14:10 -55.155800  -2.22706  11.7656   7.02000   4.74556
# 293  20040619  14:30 -55.198700  -2.23428  15.7943   5.33714  10.45710
# 294  20040619  15:12 -55.090900  -2.19436  67.4460  58.68600   8.76000
#
#      Chlorophyll_a     DIC     DOC  Transparency  Turbidity  Temperature
# ...

# %%
fig, (ax, ax2) = plt.subplots(1,2)
ax.scatter(chl['Longitude'], chl['Latitude'], c= chl['Chlorophyll_a'])
c = plt.colorbar(ax=ax2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 fig, (ax, ax2) = plt.subplots(1,2)
#       2 ax.scatter(chl['Longitude'], chl['Latitude'], c= chl['Chlorophyll_a'])
# ----> 3 c = plt.colorbar(ax=ax2)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:2133, in colorbar(mappable, cax, ax, **kwargs)
#    2131     mappable = gci()
#    2132     if mappable is None:
# -> 2133         raise RuntimeError('No mappable was found to use for colorbar '
#    2134                            'creation. First define a mappable such as '
#    2135                            'an image (with imshow) or a contour set ('
#    2136                            'with contourf).')
#    2137 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2138 return ret
#
# ...

# %%
# make plot
fig = plt.figure(figsize = (10,5))

ax = plt.gca()
fig2 = plt.scatter(chl['Longitude'], chl['Latitude'], c= np.log(chl['Chlorophyll_a']))
# fig2 = plt.scatter(lon, lat, s= 50, c= chl, cmap = 'viridis', marker= 'o', ls='-', lw= 1, edgecolor= 'black')
c = plt.colorbar(fig2, ax=ax)
c.set_label('Chlorophyll Concentration (ug/L)', fontsize= 15)
plt.xlabel('Longitude', fontsize= 15)
plt.ylabel('Latitude (m)', fontsize= 15)
plt.title('Chlorophyll Concentration at Lago Curuai, Para, Brazil (2003-2004)', fontsize = 15)
plt.grid()
#plt.savefig('Brazil_chl.png')
