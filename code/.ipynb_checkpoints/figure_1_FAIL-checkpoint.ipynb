# %%
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt

# %%
#import dataset
pad_df = pd.read_csv('pad_water_quality_2010.csv', delimiter = ',', header = 9)
display(pad_df)

#index values
lat = pad_df['Decimal Degrees'].values
depth = pad_df['m'].values
chlorophyll = pad_df['ug/L'].values

#plot data
fig = plt.figure(figsize=(10,8))
#ax = plt.gca()

chlorophyll_plot = plt.pcolormesh(lat, depth, chlorophyll, cmap= 'plasma')
c = plt.colorbar(chlorophyll, ax=ax)
#ax.plot
# Out:
#        Unnamed: 0   YYYMMDD  hh:mm  Decimal Degrees  Decimal Degrees.1  deg C
# 0     Ath Abv Cec  20100621  12:51         58.44226         -111.37828  20.46  \
# 1     Ath Abv Cec  20100621  13:19         58.44348         -111.38070  20.49
# 2      Ath Abv FC  20100621  14:12         58.45258         -111.08581  20.51
# 3      Ath Abv FC  20100621  14:21         58.45248         -111.08511  20.50
# 4      Ath Abv FC  20100621  14:29         58.45261         -111.08594  20.51
# ..            ...       ...    ...              ...                ...    ...
# 172         QF TM  20100706  11:18         58.73651         -111.41180  17.44
# 173     QF Middle  20100706  11:37         58.78519         -111.45411  18.44
# 174        QF  BM  20100706  12:00         58.83385         -111.56914  18.56
# 175   QF at Peace  20100706  12:16         58.88858         -111.60782  18.42
# 176  Peace Abv QF  20100706  12:25         58.90446         -111.61662  18.56
#
# ...
